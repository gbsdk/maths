# %% [markdown]
# # Word Embedding

# %%
from IPython.display import Image
Image(filename="/Users/anqima/maths/word_embedding.png")

# %% [markdown]
# 1. Word
# 2. Word embedding: 7 features/dimensions
# 3. Dimensionality reduction: e.g. Principal Component Analysis
# 4. Visualization of word embeddings in 2D: Euclidean distance

# %% [markdown]
# # One Hot Encoding

# %%
Image(filename="/Users/anqima/maths/one_hot_encoding.png")

# %% [markdown]
# used for categorical variable.
